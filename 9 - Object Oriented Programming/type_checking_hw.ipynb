# %%
import math

# %%
class Point:
    '''
    Represents a point in 2D space

    attributes: x (int or float), y (int or float)
    '''

    def __init__(self, input_x = 0, input_y = 0):
        self.x = input_x
        self.y = input_y

    def __str__(self):
        return f'({self.x}, {self.y})'

# %%
class Polygon:
    '''
    Represents a (possibly degenerate) polygon

    attributes: vertices (list of Point objects)
    '''

    def __init__(self, input_vertices = [Point(), Point(), Point()]):
        self.vertices = input_vertices

    def __str__(self):
        point_string = 'Vertices: '

        for i in range(len(self.vertices)):
            if i < len(self.vertices) - 1:
                point_string = point_string + str(self.vertices[i]) + ', '
            else:
                point_string = point_string + str(self.vertices[i])

        return point_string
    
    def centroid(self):
        x_sum = 0
        y_sum = 0
        
        for point in self.vertices:
            x_sum += point.x
            y_sum += point.y

        return f'({x_sum / len(self.vertices)}, {y_sum / len(self.vertices)})'

    def perimeter(self):
        result = 0

        for i in range(len(self.vertices)):
            if i + 1 < len(self.vertices):
                result += distance(self.vertices[i], self.vertices[i + 1])
            else:
                result += distance(self.vertices[i], self.vertices[0])

        return result

    def is_regular(self):
        length = distance(self.vertices[0], self.vertices[1])

        for i in range(len(self.vertices)):
            if i + 1 < len(self.vertices):
                if not distance(self.vertices[i], self.vertices[i + 1]) == length:
                    return False
            else:
                if not distance(self.vertices[i], self.vertices[0]) == length:
                    return False
                
        return True

# %%
class Triangle(Polygon):
    '''
    Represents a (possibly degenerate) triangle

    attributes: vertices (list of Point objects)
    '''

    def __init__(self, input_vertices:list[Point] = [Point(), Point(), Point()]):
        
        if not isinstance(input_vertices, list):
            raise TypeError('Constructor requires a list of Point objects.')
        elif not all(isinstance(p, Point) for p in input_vertices):
            raise TypeError('Constructor requires a list of Point objects.')
        elif not len(input_vertices) == 3:
            raise ValueError('Constructor requires a list of exactly three Point objects.')
        else:
            self.vertices = input_vertices

# %%
class Quadrilateral(Polygon):
    '''
    Represents a (possibly degenerate) quadrilateral

    attributes: vertices (list of Point objects)
    '''

    def __init__(self, input_vertices:list[Point] = [Point(), Point(), Point()]):
        if not isinstance(input_vertices, list):
            raise TypeError('Constructor requires a list of Point objects.')
        elif not all(isinstance(p, Point) for p in input_vertices):
            raise TypeError('Constructor requires a list of Point objects.')
        elif not len(input_vertices) == 4:
            raise ValueError('Constructor requires a list of exactly three Point objects.')
        else:
            self.vertices = input_vertices

# %%
def distance(point1, point2):
    '''
    Calculates the distance between two Point objects.

    param point1, point2: Point object with an x and y value
    return: the distance between the two points
    '''
    
    return math.sqrt(pow(point2.x - point1.x, 2) + pow(point2.y - point1.y, 2))

# %%
# Test Case 1
Triangle('string')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Test Case 1
# ----> 2 Triangle('string')
#
# Cell In[13], line 11, in Triangle.__init__(self, input_vertices)
#       8 def __init__(self, input_vertices:list[Point] = [Point(), Point(), Point()]):
#      10     if not isinstance(input_vertices, list):
# ---> 11         raise TypeError('Constructor requires a list of Point objects.')
#      12     elif not all(isinstance(p, Point) for p in input_vertices):
#      13         raise TypeError('Constructor requires a list of Point objects.')
#
# TypeError: Constructor requires a list of Point objects.

# %%
# Test Case 2
Triangle([Point(), Point()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Test Case 2
# ----> 2 Triangle([Point(), Point()])
#
# Cell In[13], line 15, in Triangle.__init__(self, input_vertices)
#      13     raise TypeError('Constructor requires a list of Point objects.')
#      14 elif not len(input_vertices) == 3:
# ---> 15     raise ValueError('Constructor requires a list of exactly three Point objects.')
#      16 else:
#      17     self.vertices = input_vertices
#
# ValueError: Constructor requires a list of exactly three Point objects.

# %%
# Test Case 3
Quadrilateral([Point(), Point(), 'a'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Test Case 3
# ----> 2 Quadrilateral([Point(), Point(), 'a'])
#
# Cell In[14], line 12, in Quadrilateral.__init__(self, input_vertices)
#      10     raise TypeError('Constructor requires a list of Point objects.')
#      11 elif not all(isinstance(p, Point) for p in input_vertices):
# ---> 12     raise TypeError('Constructor requires a list of Point objects.')
#      13 elif not len(input_vertices) == 4:
#      14     raise ValueError('Constructor requires a list of exactly three Point objects.')
#
# TypeError: Constructor requires a list of Point objects.
